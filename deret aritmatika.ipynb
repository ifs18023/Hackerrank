# %%
a = 5
b = 6
n = 0
hasil = 0
while True:
    if n < 72:
        print(a)
        n = n + 1
        a = a + b
        hasil = hasil + a
    else:
        break
        
print("Sn = {}".format(hasil))
# Out:
# 5
# 11
# 17
# 23
# 29
# 35
# 41
# 47
# 53
# 59
# 65
# 71
# 77
# 83
# 89
# 95
# 101
# 107
# 113
# 119
# 125
# 131
# 137
# 143
# 149
# 155
# 161
# 167
# 173
# 179
# 185
# 191
# 197
# 203
# 209
# 215
# 221
# 227
# 233
# 239
# 245
# 251
# 257
# 263
# 269
# 275
# 281
# 287
# 293
# 299
# 305
# 311
# 317
# 323
# 329
# 335
# 341
# 347
# 353
# 359
# 365
# 371
# 377
# 383
# 389
# 395
# 401
# 407
# 413
# 419
# 425
# 431
# Sn = 16128
